# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.random.uniform(0, 1, 1000)
#This generates 1000 random numbers uniformly distributed between [0,1]

# %%
plt.figure(figsize=(8, 5))
plt.hist(data, bins=100, color='skyblue', edgecolor='black')
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.title("Histogram of Uniformly Distributed Random Numbers")
plt.grid(True)

plt.savefig("uniform_histogram.pdf")
plt.show()
#This plots a histogram of the random numbers using 100 bins
